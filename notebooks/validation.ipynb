# %% [markdown]
# ## Data validation for GRIDCERF non-renewable technologies

# %%
# %matplotlib inline 

import os
import shutil
import tempfile

import rasterio
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio.mask
import seaborn as sns
import shapely.speedups
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors

from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from matplotlib.colors import ListedColormap
from mpl_toolkits.axes_grid1 import make_axes_locatable
from rasterio import features
from rasterio.plot import show, plotting_extent

# enable shapely.speedups to make the spatial queries run faster
shapely.speedups.enable()

# %% [markdown]
# ### Worker functions

# %%
def sum_rasters(raster_list) -> np.ndarray:
    """Sum all rasters in the input list and return a reclassified array having
    values of 0 == suitable and 1 == unsuitable.
    
    :param raster_list:                 List of full path with file name and extensions to the input raster files
    :type raster_list:                  list 
    
    :return:                            A 2D array of 0, 1 suitablity designation
    
    """
    
    for idx, raster in enumerate(raster_list):

        if idx == 0:
            final_array = raster_to_array(raster).astype(np.float32)

        else:

            this_array = raster_to_array(raster)
            final_array += this_array
                
    # reclassify array back to 0 == suitable, 1 == unsuitable
    return np.where(final_array == 0, 0, 1)
    

def raster_to_array(raster_file) -> np.ndarray:
    """Read in a raster file and return a 2D NumPy array.
    
    :param raster_file:                 Full path with file name and extension to the input raster file 
    :type raster_file:                  str 
    
    :return:                            A 2D array
    
    """
    
    with rasterio.open(raster_file) as src:
        return src.read(1)

    
def plot_raster(arr, title):

    fig, ax = plt.subplots(figsize=(10, 5))

    # Define the colors you want
    cmap = ListedColormap(["grey", "navy"])

    # Define a normalization from values -> colors
    norm = colors.BoundaryNorm([0, 1], 2)

    raster_plot = ax.imshow(arr, cmap=cmap)

    # Add a legend for labels
    legend_labels = {"grey": "0", "navy": "1"}

    patches = [Patch(color=color, label=label)
               for color, label in legend_labels.items()]

    ax.legend(handles=patches,
              bbox_to_anchor=(1.15, 1),
              facecolor="white")

    ax.set_title(title)

    ax.set_axis_off()
    
    return ax

# %% [markdown]
# ### Load data

# %%
# get the parent directory path to where this notebook is currently stored
root_dir = os.path.dirname(os.getcwd())

# data directory in repository
data_dir = os.path.join(root_dir, "data")

# GRIDCERF data directory from downloaded archive
gridcerf_dir = os.path.join(data_dir, "gridcerf")

# GRIDCERF reference data directory
reference_dir = os.path.join(gridcerf_dir, "reference")

# GRIDCERF source data directory
source_dir = os.path.join(gridcerf_dir, "source")

# GRIDCERF technology_specific data directory
technology_specific_dir = os.path.join(gridcerf_dir, "technology_specific")

# GRIDCERF common suitability data directory
common_dir = os.path.join(gridcerf_dir, "common")

# GRIDCERF compiled final suitability data directory
compiled_dir = os.path.join(gridcerf_dir, "compiled")

# template land mask raster
template_raster = os.path.join(reference_dir, "gridcerf_landmask.tif")

# validation directory
validation_dir = os.path.join(gridcerf_dir, 'validation')

# slope raster to apply
slope_raster = os.path.join(technology_specific_dir, 'gridcerf_srtm_slope_12pct_or_less.tif')

# EIA power plant spatialdata
power_plant_file = os.path.join(validation_dir, 'eia', 'accessed_2021-06-09', 'PowerPlants_US_EIA', 'PowerPlants_US_202004.shp')

# eia generatory inventory file downloaded from:  https://www.eia.gov/electricity/data/eia860m/xls/april_generator2021.xlsx
eia_generator_inventory_file = os.path.join(validation_dir, 'eia', 'april_generator2021.xlsx')

# administrative data
cerf_conus_file = os.path.join(validation_dir, 'admin', 'shp', 'cerf_conus_boundary.shp')
cerf_states_file = os.path.join(validation_dir, 'admin', 'shp', 'Promod_20121028_fips.shp')
cerf_raster_states_file = os.path.join(validation_dir, 'admin', 'rast', 'promod_20121028_conus.img')
stateid_to_statename_file = os.path.join(validation_dir, 'admin', 'csv', 'stateid_to_statename.csv')

# output combined common suitability layer without land mask
cerf_common_suitability_file = os.path.join(validation_dir, 'temp', 'gridcerf_common_suitability.tif')

# combined thermoelectric common suitability with land mask
cerf_common_suitability_masked_file = os.path.join(validation_dir, 'temp', 'gridcerf_common_suitability_landmask.tif')

# validation outputs
suitable_power_plants_file = os.path.join(validation_dir, 'results', 'suitable_power_plants.shp')
unsuitable_power_plants_file = os.path.join(validation_dir, 'results', 'unsuitable_power_plants.shp')

# %% [markdown]
# ### Create raster mask for CONUS grid cells

# %%
with rasterio.open(cerf_raster_states_file) as src:
    
    land_mask_arr = src.read(1)
    mask_metadata = src.meta
    
    land_mask_arr = np.where(land_mask_arr == src.nodata, np.nan, 0)

# %% [markdown]
# ### Generate a list of all CERF common suitablity rasters and extract the CRS info

# %%
raster_list = [os.path.join(common_dir, i) for i in os.listdir(common_dir) if i[-4:] == '.tif']
raster_list.append(slope_raster)

# extract the coordinate reference system from CERF's raster
with rasterio.open(raster_list[0]) as src:
    target_crs = src.crs

# %% [markdown]
# ### Create aggregate suitablity over the CONUS

# %%
for idx, raster in enumerate(raster_list):

    with rasterio.open(raster) as src:
        metadata = src.meta
        
        metadata.update({"dtype": np.uint8})
        
        if idx == 0:
            arr = src.read(1).astype(np.uint8)
            
        else:
            arr += src.read(1).astype(np.uint8)
            
# create common combined exclusion array
common_arr = np.where(arr == 0, 0, 1).astype(np.uint8)

# write aggregate common suitability as a raster have 0 for suitable, 1 for unsuitable
with rasterio.open(cerf_common_suitability_file, 'w', **metadata) as out:
    out.write(common_arr, 1)

# plot aggregate suitablity
fig, ax = plt.subplots(figsize=(10, 5))
ax.set_axis_off()
show(arr + land_mask_arr, ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Create combined thermoelectric common suitablity layer

# %%
mask_metadata.update({'dtype': 'float64'})

# write common raster incorporating land mask
with rasterio.open(cerf_common_suitability_masked_file, 'w', **mask_metadata) as out:
    out.write(common_arr + land_mask_arr, 1)

# plot
fig, ax = plt.subplots(figsize=(10, 5))
ax.set_axis_off()
show(common_arr + land_mask_arr, ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Read in EIA power plant and CERF boundary shapefiles to GeoDataFrames

# %% [markdown]
# Reproject the data to CERF's projected coordinate system

# %%
power_plant_gdf = gpd.read_file(power_plant_file).to_crs(target_crs)

boundary_gdf = gpd.read_file(cerf_conus_file).to_crs(target_crs)

states_gdf = gpd.read_file(cerf_states_file).to_crs(target_crs)

# %% [markdown]
# ### Filter out only target primary sources that correspond with CERF technologies

# %%
# filter out only target primary sources that correspond with CERF technologies; wind and solar evaluated separately 
primary_source_list = ['natural gas', 'nuclear', 'coal', 'petroleum', 'biomass']

power_plant_gdf = power_plant_gdf.loc[power_plant_gdf['PrimSource'].isin(primary_source_list)]

# %% [markdown]
# ### Visualize all EIA power plants with applicable technologies over CERF's CONUS extent

# %%
fig, ax = plt.subplots()
plt.title("All EIA power plants over CERF's CONUS extent")

boundary_gdf.plot(ax=ax, facecolor='gray')
power_plant_gdf.plot(ax=ax, color='blue', markersize=2)

ax.set_axis_off()

# %% [markdown]
# ### Only keep power plants that are within CERF's CONUS extent

# %%
# get power plants that are within CERF's CONUS boundary
power_plant_mask = power_plant_gdf.within(boundary_gdf.loc[0, 'geometry'])
power_plant_conus = power_plant_gdf.loc[power_plant_mask].copy()

# %% [markdown]
# ### Only keep power plants >= 80 MW

# %%
power_plant_conus = power_plant_conus.loc[power_plant_conus['Total_MW'] >= 80].copy()

# %% [markdown]
# ### Only keep power plants that became operational during or after 2000

# %%
# load EIA montly generator inventory
gen_df = pd.read_excel(eia_generator_inventory_file, 
                       sheet_name='Operating', 
                       engine='openpyxl', 
                       skiprows=2, 
                       usecols=['Plant ID', 'Operating Year'])

# reduce eia860 data to only include plant if the first generator was operational during or after 2000
gen_df = gen_df.groupby('Plant ID', as_index=False).min()

# keep only operational during or after 2000
gen_df = gen_df.loc[gen_df['Operating Year'] >= 2000].copy()

# get an array of 'Plant_Code' that meet the criteria
valid_plant_codes = gen_df['Plant ID'].unique().astype(int)

# only keep valid power plants
power_plant_conus = power_plant_conus.loc[power_plant_conus['Plant_Code'].isin(valid_plant_codes)].copy()

# extract x,y coords to list of tuples
power_plant_conus['xcoord'] = power_plant_conus.geometry.x
power_plant_conus['ycoord'] = power_plant_conus.geometry.y
coords = [(x,y) for x, y in zip(power_plant_conus['xcoord'], power_plant_conus['ycoord'])]

# %% [markdown]
# ### Visualize EIA power plants with applicable technologies that are within GRIDCERF's CONUS extent

# %%
fig, ax = plt.subplots()
plt.title("EIA power plants within GRIDCERF's CONUS extent")

boundary_gdf.plot(ax=ax, facecolor='gray')
power_plant_conus.plot(ax=ax, color='blue', markersize=2)

ax.set_axis_off()

# %% [markdown]
# ## Determine which power plants fall on suitable and unsuitable land

# %% [markdown]
# ### Validation for individual common suitablity layers for the CONUS

# %%
# dictionary to store outputs in
d = {'layer': [], 'invalid': [], 'valid': []}

# total number of power plants for the CONUS
n_power_plants_conus = len(coords)

# update suitability for each power plant once it is within a grid cell that is unsuitable
for raster in raster_list:

    with rasterio.open(raster) as src:

        # extract the suitability value (0 == suitable; 1 == unsuitable) for each power plant
        extract_suitability_at_points = [int(i[0]) for i in src.sample(coords)]
        
        # get the count of unsuitable designations
        n_unsuitable_plants = len([i for i in extract_suitability_at_points if i == 1])
        
        # append the results to the output dictionary
        d['layer'].append(os.path.basename(raster.lower()))
        d['invalid'].append(n_unsuitable_plants)
        d['valid'].append(n_power_plants_conus - n_unsuitable_plants)

# convert the output to a pandas data frame
layer_specific_diagnostics = pd.DataFrame(d)

layer_specific_diagnostics['fraction'] = layer_specific_diagnostics['invalid'] / n_power_plants_conus

layer_specific_diagnostics
# Out:
#                                                 layer  invalid  valid  \
# 0       gridcerf_wdpa_state_protected_lands_conus.tif       32    465
# 1       gridcerf_blm_nlcs_national_monument_conus.tif        0    497
# 2              gridcerf_blm_nlcs_wilderness_conus.tif        0    497
# 3           gridcerf_usfws_critical_habitat_conus.tif       23    474
# 4          gridcerf_usgs_padus_class_1_to_2_conus.tif        3    494
# 5            gridcerf_usgs_wilderness_areas_conus.tif        0    497
# 6           gridcerf_wdpa_tnc_managed_lands_conus.tif        3    494
# 7   gridcerf_blm_nlcs_outstanding_natural_areas_co...        0    497
# 8              gridcerf_nps_historic_trails_conus.tif       38    459
# 9   gridcerf_usfs_administrative_boundaries_conus.tif        0    497
# 10           gridcerf_usfs_wilderness_areas_conus.tif        0    497
# 11       gridcerf_usfws_special_designation_conus.tif        0    497
# 12  gridcerf_usfws_national_wild_scenic_river_syst...        1    496
# 13                   gridcerf_nlcd_wetlands_conus.tif        4    493
# 14   gridcerf_nps_administrative_boundaries_conus.tif        1    496
# 15   gridcerf_blm_surface_management_agency_areas.tif        9    488
# 16             gridcerf_epa_class1_airsheds_conus.tif        0    497
# 17    gridcerf_usfws_national_realty_tracts_conus.tif        8    489
# 18               gridcerf_nps_scenic_trails_conus.tif        7    490
# 19  gridcerf_blm_nlcs_wilderness_study_areas_conus...        0    497
# 20              gridcerf_srtm_slope_12pct_or_less.tif        3    494
#
#     fraction
# 0   0.064386
# 1   0.000000
# 2   0.000000
# 3   0.046278
# 4   0.006036
# 5   0.000000
# 6   0.006036
# 7   0.000000
# 8   0.076459
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.002012
# 13  0.008048
# 14  0.002012
# 15  0.018109
# 16  0.000000
# 17  0.016097
# 18  0.014085
# 19  0.000000
# 20  0.006036

# %% [markdown]
# ### Validation for all common suitability layers combined

# %%
# stage suitability designation for each power plant
power_plant_conus['suitability'] = 0

# update suitability for each power plant once it is within a grid cell that is unsuitable
for raster in raster_list:

    with rasterio.open(raster) as src:

        # extract the suitability value (0 == suitable; 1 == unsuitable) for each power plant
        extract_suitability_at_points = [int(i[0]) for i in src.sample(coords)]

    # if unsuitable, update value
    power_plant_conus['suitability'] = np.where(power_plant_conus['suitability'] < extract_suitability_at_points,
                                                extract_suitability_at_points,
                                                power_plant_conus['suitability'])

suitable_power_plants = power_plant_conus.loc[power_plant_conus['suitability'] == 0].copy()
unsuitable_power_plants = power_plant_conus.loc[power_plant_conus['suitability'] == 1].copy()

# add to diagnostic data frame
total_common = ['combined_common_suitability_layers', 
                unsuitable_power_plants.shape[0], 
                suitable_power_plants.shape[0], 
                unsuitable_power_plants.shape[0] / n_power_plants_conus]

layer_specific_diagnostics.loc[len(layer_specific_diagnostics.index)] = total_common

# write out suitability power plant shapefiles
suitable_power_plants[['geometry', 'PrimSource']].to_file(suitable_power_plants_file)
unsuitable_power_plants[['geometry', 'PrimSource']].to_file(unsuitable_power_plants_file)

# %% [markdown]
# ##### Plot map

# %%
# generate plot
sns.set(font_scale=2) 

fig, ax = plt.subplots(figsize=(20, 10))

plt.title("EIA power plant interactions with GRIDCERF common suitability")

suitable_color = "#d0e1e1"
unsuitable_color = "#f3f2f2"

cmap = ListedColormap([suitable_color, unsuitable_color])

with rasterio.open(cerf_common_suitability_masked_file) as src:
    
    # boundary_gdf.plot(ax=ax, facecolor='lightgray')
    show(src, ax=ax, cmap=cmap) #, interpolation='none', ax=ax)
    states_gdf.boundary.plot(ax=ax, edgecolor='gray', lw=0.2)
    boundary_gdf.boundary.plot(ax=ax, edgecolor='gray', lw=0.8)
    suitable_power_plants.plot(ax=ax, color='green', markersize=5)
    unsuitable_power_plants.plot(ax=ax, color='red', markersize=5)

    # construct legend
    legend_elements = [Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=12, label='Valid'),
                       Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markersize=12, label='Invalid'),
                       Patch(facecolor=suitable_color, label='Suitable'),
                       Patch(facecolor=unsuitable_color, label='Unsuitable')]

    ax.legend(handles=legend_elements,
              bbox_to_anchor=(1.05, 1),
              facecolor="white",
              frameon=False)

    ax.set_axis_off()

    sns.set(font_scale=1)

n_suitable = suitable_power_plants.shape[0]
n_unsuitable = unsuitable_power_plants.shape[0]
    
print(f"There are {n_suitable} valid power plants.")
print(f"There are {n_unsuitable} invalid power plants.\n")
# Out:
# There are 393 valid power plants.
# There are 104 invalid power plants.

# %% [markdown]
# ### Natural gas power plants make up the majority of power plants sited since 2000

# %%
total_ppts = power_plant_conus[['geometry', 'PrimSource']].groupby('PrimSource').count().copy()
total_ppts.reset_index(inplace=True)
total_ppts.rename(columns={'geometry': 'count'}, inplace=True)

total_ppts['percent'] = (total_ppts['count'] / total_ppts['count'].sum()) * 100

print("Composition of all evaluated power plants:")
total_ppts.sort_values(by='percent', ascending=False)
# Out:
# Composition of all evaluated power plants:
#     PrimSource  count    percent
# 2  natural gas    471  94.768612
# 1         coal     18   3.621730
# 3    petroleum      5   1.006036
# 0      biomass      3   0.603622

# %%
print("Composition of all power plants co-occuring on suitable grid cells:")
n_suitable_by_tech = suitable_power_plants[['PrimSource', 'suitability']].groupby('PrimSource').count()
n_suitable_by_tech.sort_values(by='suitability', ascending=False)
# Out:
# Composition of all power plants co-occuring on suitable grid cells:
#              suitability
# PrimSource
# natural gas          373
# coal                  16
# biomass                3
# petroleum              1

# %%
print("Composition of all power plants co-occuring on unsuitable grid cells:")
n_unsuitable_by_tech = unsuitable_power_plants[['PrimSource', 'suitability']].groupby('PrimSource').count()
n_unsuitable_by_tech.sort_values(by='suitability', ascending=False)
# Out:
# Composition of all power plants co-occuring on unsuitable grid cells:
#              suitability
# PrimSource
# natural gas           98
# petroleum              4
# coal                   2

# %% [markdown]
# ### Fraction of invalidities caused by each layer
#
# This breaks down validity by using only on layer at a time as the exclusion layer.  For example, if `cerf_nlcd_wetlands_1km_2019_conus.tif` were the only exclusion layer in use, 66 power plants would be considered invalid out of all 497 power plants investigated.

# %%
layer_specific_diagnostics.sort_values(by='fraction', ascending=False)
# Out:
#                                                 layer  invalid  valid  \
# 21                 combined_common_suitability_layers      104    393
# 8              gridcerf_nps_historic_trails_conus.tif       38    459
# 0       gridcerf_wdpa_state_protected_lands_conus.tif       32    465
# 3           gridcerf_usfws_critical_habitat_conus.tif       23    474
# 15   gridcerf_blm_surface_management_agency_areas.tif        9    488
# 17    gridcerf_usfws_national_realty_tracts_conus.tif        8    489
# 18               gridcerf_nps_scenic_trails_conus.tif        7    490
# 13                   gridcerf_nlcd_wetlands_conus.tif        4    493
# 4          gridcerf_usgs_padus_class_1_to_2_conus.tif        3    494
# 20              gridcerf_srtm_slope_12pct_or_less.tif        3    494
# 6           gridcerf_wdpa_tnc_managed_lands_conus.tif        3    494
# 14   gridcerf_nps_administrative_boundaries_conus.tif        1    496
# 12  gridcerf_usfws_national_wild_scenic_river_syst...        1    496
# 1       gridcerf_blm_nlcs_national_monument_conus.tif        0    497
# 10           gridcerf_usfs_wilderness_areas_conus.tif        0    497
# 9   gridcerf_usfs_administrative_boundaries_conus.tif        0    497
# 16             gridcerf_epa_class1_airsheds_conus.tif        0    497
# 2              gridcerf_blm_nlcs_wilderness_conus.tif        0    497
# 7   gridcerf_blm_nlcs_outstanding_natural_areas_co...        0    497
# 19  gridcerf_blm_nlcs_wilderness_study_areas_conus...        0    497
# 5            gridcerf_usgs_wilderness_areas_conus.tif        0    497
# 11       gridcerf_usfws_special_designation_conus.tif        0    497
#
#     fraction
# 21  0.209256
# 8   0.076459
# 0   0.064386
# 3   0.046278
# 15  0.018109
# 17  0.016097
# 18  0.014085
# 13  0.008048
# 4   0.006036
# 20  0.006036
# 6   0.006036
# 14  0.002012
# 12  0.002012
# 1   0.000000
# 10  0.000000
# 9   0.000000
# 16  0.000000
# 2   0.000000
# 7   0.000000
# 19  0.000000
# 5   0.000000
# 11  0.000000

# %% [markdown]
# ##### Plot bar

# %%
display_df = layer_specific_diagnostics.sort_values(by='fraction', ascending=False).copy()

sns.set(font_scale=1.4) 

fig, ax = plt.subplots(figsize=(10, 14))

ax = sns.barplot(x="fraction", y="layer", data=display_df, palette="flare")

ax.set(ylabel=None, 
       title='Fraction of total power plants on unsuitable common grid cells')

sns.set(font_scale=1)

# %% [markdown]
# ### Composition of invalid plants

# %%
# remove aggregate common metric
layer_composition = layer_specific_diagnostics.loc[layer_specific_diagnostics['layer'] != 'combined_common_suitability_layers'].copy()

# %%
# calculate the fraction of invalid by layer to the total number of unsuitable power plants (this number is lower than
#  the sum of invalid in this data frame because multiple layers can cause unsuitability to occur for each grid cell)
layer_composition['contribution_to_invalid'] = layer_composition['invalid'] / n_unsuitable

layer_composition.sort_values(by='contribution_to_invalid', ascending=False)
# Out:
#                                                 layer  invalid  valid  \
# 8              gridcerf_nps_historic_trails_conus.tif       38    459
# 0       gridcerf_wdpa_state_protected_lands_conus.tif       32    465
# 3           gridcerf_usfws_critical_habitat_conus.tif       23    474
# 15   gridcerf_blm_surface_management_agency_areas.tif        9    488
# 17    gridcerf_usfws_national_realty_tracts_conus.tif        8    489
# 18               gridcerf_nps_scenic_trails_conus.tif        7    490
# 13                   gridcerf_nlcd_wetlands_conus.tif        4    493
# 20              gridcerf_srtm_slope_12pct_or_less.tif        3    494
# 6           gridcerf_wdpa_tnc_managed_lands_conus.tif        3    494
# 4          gridcerf_usgs_padus_class_1_to_2_conus.tif        3    494
# 12  gridcerf_usfws_national_wild_scenic_river_syst...        1    496
# 14   gridcerf_nps_administrative_boundaries_conus.tif        1    496
# 7   gridcerf_blm_nlcs_outstanding_natural_areas_co...        0    497
# 9   gridcerf_usfs_administrative_boundaries_conus.tif        0    497
# 1       gridcerf_blm_nlcs_national_monument_conus.tif        0    497
# 11       gridcerf_usfws_special_designation_conus.tif        0    497
# 5            gridcerf_usgs_wilderness_areas_conus.tif        0    497
# 16             gridcerf_epa_class1_airsheds_conus.tif        0    497
# 2              gridcerf_blm_nlcs_wilderness_conus.tif        0    497
# 19  gridcerf_blm_nlcs_wilderness_study_areas_conus...        0    497
# 10           gridcerf_usfs_wilderness_areas_conus.tif        0    497
#
#     fraction  contribution_to_invalid
# 8   0.076459                 0.365385
# 0   0.064386                 0.307692
# 3   0.046278                 0.221154
# 15  0.018109                 0.086538
# 17  0.016097                 0.076923
# 18  0.014085                 0.067308
# 13  0.008048                 0.038462
# 20  0.006036                 0.028846
# 6   0.006036                 0.028846
# 4   0.006036                 0.028846
# 12  0.002012                 0.009615
# 14  0.002012                 0.009615
# 7   0.000000                 0.000000
# 9   0.000000                 0.000000
# 1   0.000000                 0.000000
# 11  0.000000                 0.000000
# 5   0.000000                 0.000000
# 16  0.000000                 0.000000
# 2   0.000000                 0.000000
# 19  0.000000                 0.000000
# 10  0.000000                 0.000000

# %% [markdown]
# ##### Plot

# %%
display_comp_df = layer_composition.sort_values(by='contribution_to_invalid', ascending=False).copy()

sns.set(font_scale=1.4) 

fig, ax = plt.subplots(figsize=(10, 14))

ax = sns.barplot(x="contribution_to_invalid", y="layer", data=display_comp_df, palette="flare")

ax.set(ylabel=None, 
       title='Contribution to invalid power plants')

sns.set(font_scale=1)

# %% [markdown]
# ### Determine the number of invalid power plants for each state

# %%
state_list = states_gdf['ObjectID'].unique()

state_d = {'state_name': [], 'invalid': [], 'valid': [], 'fraction': []}

with rasterio.open(cerf_common_suitability_file) as src:

    for i in state_list:

        target_state_gdf = states_gdf.loc[states_gdf['ObjectID'] == i].copy()

        state_power_plant_mask = power_plant_gdf.within(target_state_gdf.geometry.values[0])

        state_power_plant = power_plant_gdf.loc[state_power_plant_mask].copy()

        state_power_plant['xcoord'] = state_power_plant.geometry.x
        state_power_plant['ycoord'] = state_power_plant.geometry.y

        state_coords = [(x,y) for x, y in zip(state_power_plant['xcoord'], state_power_plant['ycoord'])]
        
        n_power_plants_state = len(state_coords)
        
        # extract the suitability value (0 == suitable; 1 == unsuitable) for each power plant
        state_extract_suitability_at_points = [int(i[0]) for i in src.sample(state_coords)]
        
        # get the count of unsuitable designations
        n_unsuitable_plants_state = len([i for i in state_extract_suitability_at_points if i == 1])
        
        n_suitable_plants_state = n_power_plants_state - n_unsuitable_plants_state
        
        state_d['state_name'].append(i)
        state_d['invalid'].append(n_unsuitable_plants_state)
        state_d['valid'].append(n_suitable_plants_state)
        state_d['fraction'].append(n_unsuitable_plants_state / n_power_plants_state)

states_diag_df = pd.DataFrame(state_d)

# %% [markdown]
# ##### Plot map

# %%
# get a dictionary of state ids to invalid fraction
states_eval = states_diag_df.copy()
states_eval.set_index('state_name', inplace=True)
state_lookup = states_eval['fraction'].to_dict()

# apply fraction to the states geodataframe
states_gdf['fraction'] = states_gdf['ObjectID'].map(state_lookup)

# plot map
sns.set(font_scale=2) 

fig, ax = plt.subplots(1, 1, figsize=(15, 20))

plt.title("Fraction of EIA power plants sited on CERF unsuitable grid cells")

divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="5%", pad=0.1)

s = states_gdf.plot(column='fraction', 
                ax=ax,
                edgecolor='lightgrey',
                legend=True,
                legend_kwds={'label': "Fraction of invalid power plants", 
                             'orientation': "horizontal"},
                cax=cax)

boundary_gdf.boundary.plot(ax=ax, edgecolor='gray', lw=0.8)

ax.set_axis_off()

sns.set(font_scale=1)

# %% [markdown]
# ##### Plot bar

# %% [markdown]
# ### Data prep for states (y-axis) to layers (x-axis) for fraction of invalid power plants

# %%
state_list = states_gdf['ObjectID'].unique()

heat_df = pd.DataFrame({'state_name': state_list})

head_d = {}

for raster in raster_list:
    
    base_name = os.path.basename(raster).lower()

    with rasterio.open(raster) as src:

        l = []
        
        for i in state_list:

            target_state_gdf = states_gdf.loc[states_gdf['ObjectID'] == i].copy()

            state_power_plant_mask = power_plant_gdf.within(target_state_gdf.geometry.values[0])

            state_power_plant = power_plant_gdf.loc[state_power_plant_mask].copy()

            state_power_plant['xcoord'] = state_power_plant.geometry.x
            state_power_plant['ycoord'] = state_power_plant.geometry.y

            state_coords = [(x,y) for x, y in zip(state_power_plant['xcoord'], state_power_plant['ycoord'])]

            n_power_plants_state = len(state_coords)

            # extract the suitability value (0 == suitable; 1 == unsuitable) for each power plant
            state_extract_suitability_at_points = [int(i[0]) for i in src.sample(state_coords)]

            # get the count of unsuitable designations
            n_unsuitable_plants_state = len([i for i in state_extract_suitability_at_points if i == 1])

            n_suitable_plants_state = n_power_plants_state - n_unsuitable_plants_state
            
            # fraction of invalid plants for the target state per layer
            l.append(n_unsuitable_plants_state / n_power_plants_state)

        heat_df[base_name] = l

# %% [markdown]
# #### Number of states having an invalidity from wetlands

# %%
n_states_invalid = dfx.loc[dfx['gridcerf_nps_historic_trails_conus.tif'] > 0].shape[0]

print(f"Historic trails invalidities were spread across {n_states_invalid} states.")
# Out:
# Historic trails invalidities were spread across 35 states.

# %% [markdown]
# ### Create the proximity of invalid plants to a suitable grid cell

# %% [markdown]
# Currently, I do this in ArcMap using the following procedure:
# - add the created `<mydir>/temp/cerf_common_suitability_landmask.tif` file
# - add `<mydir>/results/unsuitable_power_plants.shp`
# - Run the `Set Null` tool using `VALUE = 1` and the suitability raster as the input and constant
# - Run the `Euclidean Distance` tool on the set null output raster
# - Run the `Extract Values to Points` to using the output of Euclidean distance and the unsuitable points
# - Save the output as `<mydir>/results/unsuitable_power_plants_dist.shp`

# %%
prox_gdf = gpd.read_file(os.path.join(validation_dir, 'results', 'unsuitable_power_plants_dist.shp'))

prox_gdf['dist_to_suit_km'] = prox_gdf['RASTERVALU'] / 1000

# plot histogram
prox_gdf['dist_to_suit_km'].hist()
# Out:
# <AxesSubplot:>

# %%
n_within_1km = prox_gdf.loc[prox_gdf['dist_to_suit_km'] <= 1 ].shape[0]

rmse = str(np.around(np.sqrt((prox_gdf['dist_to_suit_km'].values**2).mean()), 2))

print(f"There are {n_within_1km} invalid plants within 1-km of a suitable grid cell.")
print(f"The RMSE of all invalid power plants distance to a near suitability grid cell is:  {rmse}-km")
print(f"Technologies having an invalid designation:  {', '.join(prox_gdf['PrimSource'].unique().tolist())}")

dist_max = prox_gdf['dist_to_suit_km'].max()

print(f"The maximum distance from an invalid grid cell to a suitable one is {dist_max}-km")
# Out:
# There are 72 invalid plants within 1-km of a suitable grid cell.
# The RMSE of all invalid power plants distance to a near suitability grid cell is:  2.31-km
# Technologies having an invalid designation:  natural gas, petroleum, coal
# The maximum distance from an invalid grid cell to a suitable one is 12.0-km

# %%
prox_gdf.loc[prox_gdf['dist_to_suit_km'] <= 2 ].shape[0]
# Out:
# 87

# %%
dist_bins = [(0, 1), (1, 2), (2, 5), (5, 13)]

for i in dist_bins:
    
    x = prox_gdf.loc[(prox_gdf['dist_to_suit_km'] > i[0]) & (prox_gdf['dist_to_suit_km'] <= i[1])].shape[0]
    print(x)
# Out:
# 72
# 15
# 13
# 4

# %%
prox_gdf.loc[prox_gdf['PrimSource'] == 'coal']
# Out:
#    PrimSource   RASTERVALU                        geometry  dist_to_suit_km
# 20       coal  1414.213623   POINT (477273.675 498600.381)         1.414214
# 73       coal  1000.000000  POINT (542626.831 -188344.025)         1.000000

# %% [markdown]
# #### Bin distance to suitability

# %%
unsuitable_1 = prox_gdf.loc[prox_gdf['dist_to_suit_km'] <= 1.0].copy()

unsuitable_2 = prox_gdf.loc[(prox_gdf['dist_to_suit_km'] > 1.0) &
                                          (prox_gdf['dist_to_suit_km'] <= 2.0)].copy()

unsuitable_3 = prox_gdf.loc[(prox_gdf['dist_to_suit_km'] > 2.0) &
                                          (prox_gdf['dist_to_suit_km'] <= 5.0)].copy()

unsuitable_4 = prox_gdf.loc[prox_gdf['dist_to_suit_km'] > 5.0].copy()

# %%
unsuitable_4
# Out:
#      PrimSource    RASTERVALU                         geometry  \
# 29  natural gas   5099.019531  POINT (-2221863.052 363744.709)
# 37  natural gas   7615.772949  POINT (-2206340.880 331412.908)
# 41  natural gas  12000.000000    POINT (769220.422 212458.590)
# 95  natural gas   5385.165039  POINT (-122317.930 -820189.016)
#
#     dist_to_suit_km
# 29         5.099020
# 37         7.615773
# 41        12.000000
# 95         5.385165

# %% [markdown]
# #### Plot map

# %%
# generate plot
sns.set(font_scale=2) 

fig, ax = plt.subplots(figsize=(20, 10))

# plt.title("EIA power plant interactions with CERF common suitability")

suitable_color = "#d0e1e1"
unsuitable_color = "#f3f2f2"

cmap = ListedColormap([suitable_color, unsuitable_color])

# colorblind friendly colors
bin_1_color = '#FFE700'
bin_2_color = '#1ACD54'
bin_3_color = '#40908E'
bin_4_color = '#4B0057'

with rasterio.open(cerf_common_suitability_masked_file) as src:
    
    show(src, ax=ax, cmap=cmap) #, interpolation='none', ax=ax)
    states_gdf.boundary.plot(ax=ax, edgecolor='gray', lw=0.2)
    boundary_gdf.boundary.plot(ax=ax, edgecolor='gray', lw=0.8)

    # bin 1
    nat_gas_1 = unsuitable_1.loc[unsuitable_1['PrimSource'] == 'natural gas'].copy()
    coal_1 = unsuitable_1.loc[unsuitable_1['PrimSource'] == 'coal'].copy()
    oil_1 = unsuitable_1.loc[unsuitable_1['PrimSource'] == 'petroleum'].copy()
    biomass_1 = unsuitable_1.loc[unsuitable_1['PrimSource'] == 'biomass'].copy()

    nat_gas_1.plot(ax=ax, color=bin_1_color, markersize=50, marker='o', linewidth=0.2, edgecolor='black')
    coal_1.plot(ax=ax, color=bin_1_color, markersize=100, marker='*', linewidth=0.2, edgecolor='black')
    oil_1.plot(ax=ax, color=bin_1_color, markersize=100, marker='^', linewidth=0.2, edgecolor='black')
    biomass_1.plot(ax=ax, color=bin_1_color, markersize=100, marker='s', linewidth=0.2, edgecolor='black')
    
    # bin 2
    nat_gas_2 = unsuitable_2.loc[unsuitable_2['PrimSource'] == 'natural gas'].copy()
    coal_2 = unsuitable_2.loc[unsuitable_2['PrimSource'] == 'coal'].copy()
    oil_2 = unsuitable_2.loc[unsuitable_2['PrimSource'] == 'petroleum'].copy()
    biomass_2 = unsuitable_2.loc[unsuitable_2['PrimSource'] == 'biomass'].copy()

    nat_gas_2.plot(ax=ax, color=bin_2_color, markersize=50, marker='o', linewidth=0.2, edgecolor='black')
    coal_2.plot(ax=ax, color=bin_2_color, markersize=100, marker='*', linewidth=0.2, edgecolor='black')
    oil_2.plot(ax=ax, color=bin_2_color, markersize=100, marker='^', linewidth=0.2, edgecolor='black')
    biomass_2.plot(ax=ax, color=bin_2_color, markersize=100, marker='s', linewidth=0.2, edgecolor='black')
    
    # bin 3
    nat_gas_3 = unsuitable_3.loc[unsuitable_3['PrimSource'] == 'natural gas'].copy()
    coal_3 = unsuitable_3.loc[unsuitable_3['PrimSource'] == 'coal'].copy()
    oil_3 = unsuitable_3.loc[unsuitable_3['PrimSource'] == 'petroleum'].copy()
    biomass_3 = unsuitable_3.loc[unsuitable_3['PrimSource'] == 'biomass'].copy()

    nat_gas_3.plot(ax=ax, color=bin_3_color, markersize=50, marker='o', linewidth=0.2, edgecolor='black')
    coal_3.plot(ax=ax, color=bin_3_color, markersize=100, marker='*', linewidth=0.2, edgecolor='black')
    oil_3.plot(ax=ax, color=bin_3_color, markersize=100, marker='^', linewidth=0.2, edgecolor='black')
    biomass_3.plot(ax=ax, color=bin_3_color, markersize=100, marker='s', linewidth=0.2, edgecolor='black')

    # bin 4
    nat_gas_4 = unsuitable_4.loc[unsuitable_4['PrimSource'] == 'natural gas'].copy()
    coal_4 = unsuitable_4.loc[unsuitable_4['PrimSource'] == 'coal'].copy()
    oil_4 = unsuitable_4.loc[unsuitable_4['PrimSource'] == 'petroleum'].copy()
    biomass_4 = unsuitable_4.loc[unsuitable_4['PrimSource'] == 'biomass'].copy()

    nat_gas_4.plot(ax=ax, color=bin_4_color, markersize=50, marker='o', linewidth=0.2, edgecolor='black')
    coal_4.plot(ax=ax, color=bin_4_color, markersize=100, marker='*', linewidth=0.2, edgecolor='black')
    oil_4.plot(ax=ax, color=bin_4_color, markersize=100, marker='^', linewidth=0.2, edgecolor='black')
    biomass_4.plot(ax=ax, color=bin_4_color, markersize=100, marker='s', linewidth=0.2, edgecolor='black')

    ax.set_axis_off()

    sns.set(font_scale=1)

    
output_fig = os.path.join(validation_dir, 'results', 'validation_map.png')

plt.savefig(output_fig, dpi=350, facecolor='w', edgecolor='w',
            orientation='portrait', papertype=None, format=None,
            transparent=False, bbox_inches=None, pad_inches=0.1,
            frameon=None, metadata=None)
# Out:
# /Users/d3y010/.pyenv/versions/py3.9.2_cerf/lib/python3.9/site-packages/geopandas/plotting.py:678: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(
# /Users/d3y010/.pyenv/versions/py3.9.2_cerf/lib/python3.9/site-packages/geopandas/plotting.py:678: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(
# /Users/d3y010/.pyenv/versions/py3.9.2_cerf/lib/python3.9/site-packages/geopandas/plotting.py:678: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(
# /Users/d3y010/.pyenv/versions/py3.9.2_cerf/lib/python3.9/site-packages/geopandas/plotting.py:678: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(
# <ipython-input-41-d8140003a2fa>:76: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(output_fig, dpi=350, facecolor='w', edgecolor='w',
# <ipython-input-41-d8140003a2fa>:76: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(output_fig, dpi=350, facecolor='w', edgecolor='w',

# %%
prox_gdf['bin'] = 0

prox_gdf['bin'] = np.where(prox_gdf['dist_to_suit_km'] <= 1.0, 
                           1, 
                           prox_gdf['bin'])

prox_gdf['bin'] = np.where((prox_gdf['dist_to_suit_km'] > 1.0) &
                           (prox_gdf['dist_to_suit_km'] <= 2.0), 
                           2, 
                           prox_gdf['bin'])

prox_gdf['bin'] = np.where((prox_gdf['dist_to_suit_km'] > 2.0) &
                           (prox_gdf['dist_to_suit_km'] <= 5.0), 
                           3, 
                           prox_gdf['bin'])

prox_gdf['bin'] = np.where(prox_gdf['dist_to_suit_km'] > 5.0, 
                           4, 
                           prox_gdf['bin'])

# %%
prox_gdf.bin.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Generate colorbar for plot

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
freq = prox_gdf.bin.value_counts()

dk = pd.DataFrame({'bin': [1, 2, 3, 4], 
                   'count': [freq.iloc[0], 
                             freq.iloc[1], 
                             freq.iloc[2], 
                             freq.iloc[3]
                            ],
                   'group': [0, 0, 0, 0]})

dk
# Out:
#    bin  count  group
# 0    1     72      0
# 1    2     15      0
# 2    3     13      0
# 3    4      4      0

# %%
def change_width(ax, new_value) :
    
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)


plt.figure(figsize=(4, 10))

bin_1_color = '#FFE700'
bin_2_color = '#1ACD54'
bin_3_color = '#40908E'
bin_4_color = '#4B0057'

width = [2]

bar1 = sns.barplot(x="bin",  y="count", data=dk.loc[dk['bin'] >= 1].groupby('group').sum().reset_index(), color=bin_1_color)
bar2 = sns.barplot(x="bin",  y="count", data=dk.loc[dk['bin'] >= 2].groupby('group').sum().reset_index(), color=bin_2_color)
bar3 = sns.barplot(x="bin",  y="count", data=dk.loc[dk['bin'] >= 3].groupby('group').sum().reset_index(), color=bin_3_color)
bar4 = sns.barplot(x="bin",  y="count", data=dk.loc[dk['bin'] >= 4].groupby('group').sum().reset_index(), color=bin_4_color)

change_width(bar1, .08)
